# %% [markdown]
# <a href="https://colab.research.google.com/github/JungYeoni/tobigs-25th/blob/%EA%B3%BC%EC%A0%9C_%EC%A0%9C%EC%B6%9C/Week4/GenAI/%EC%9D%B4%EC%A0%95%EC%97%B0/Week4_2%E1%84%80%E1%85%AD%E1%84%89%E1%85%B5_GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐻‍❄️ 투빅스 정규세션 4주차 1교시 Generative AI 코드 과제 🐻‍❄️

# %% [markdown]
# 이번 과제에서는 VAE 모델과 DCGAN 모델을 직접 구현 및 학습하여 이미지를 생성해보고, 그 결과를 비교해보겠습니다.
#
# - **VAE(Variational AutoEncoder)**: 입력 데이터를 저차원의 잠재 공간(latent space)으로 압축한 뒤, 이 공간의 확률 분포를 기반으로 다시 원본 데이터를 복원 및 생성하도록 하는 모델
#
# - **GAN(Generative Adversarial Network)**: 생성자(Generator)와 판별자(Discriminator)라는 두 개의 네트워크가 서로 경쟁하며 학습하는 모델
#   * Generator: Random noise를 입력받아 진짜(Real) 같은 가짜(Fake) 데이터를 생성 (=위조지폐범)
#   * Discriminator: 입력받은 데이터가 Real인지 Fake인지 구분 (=경찰)
#
# - **DCGAN (Deep Convolutional GAN)**: 기존 GAN은 단순한 MLP(Multi-Layer Perceptron) 구조인 반면, DCGAN은 이를 Convolutional 구조로 확장하여 이미지의 생성 성능을 향상시킨 모델

# %% [markdown]
# ### **모듈 임포트 및 디바이스 설정**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### **데이터셋 준비 (MNIST dataset)**

# %%
batch_size = 128
epochs = 30

transform = transforms.Compose([
    transforms.ToTensor()
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 501kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.56MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.19MB/s]

# %% [markdown]
# ## **VAE(Variational AutoEncoder) 모델 정의 및 학습**
#
# * Encoder: 입력 데이터 x를 받아 잠재 공간(Latent Space)의 파라미터를 추출
#   * 고차원의 입력데이터를 저차원의 평균과 로그 분산으로 변환
#     * 💡 빈칸 채우기 hint) `self.fc1`을 거쳐 특징을 추출한 뒤, 두 개의 서로 다른 선형 레이어를 통해 각각 평균과 로그 분산을 계산
#
# * Latent Space & Reparameterization
#   * 잠재 변수 z를 직접 고정된 값으로 뽑는 것이 아니라, encoder가 만든 분포(평균, 로그 분산)에서 샘플링함
#   * Reparameterization Trick: backpropagation는 샘플링 연산을 통과할 수 없다는 문제를 해결하기 위해 샘플링 과정을 미분 가능한 형태로 만들기 위한 수식
#
# * Decoder
#   * 샘플링된 잠재 변수 z를 다시 원래의 입력 데이터 차원으로 복원

# %% [markdown]
# ![image_vae.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/NoviceStone/VAE/blob/master/models.py

# %%
class VAE(nn.Module):

    def __init__(self, input_size=784, hidden_size=400, latent_size=20, data_type="binary"):
        super(VAE, self).__init__()

        # Encoder: layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc21 = nn.Linear(hidden_size, latent_size)  # 평균(mu)
        self.fc22 = nn.Linear(hidden_size, latent_size)  # 로그 분산(logvar)

        # Decoder: layers
        self.fc3 = nn.Linear(latent_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, input_size)

        self.data_type = data_type

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        mean = self.fc21(h1) # 🤔 빈칸을 채워주세요
        log_var = self.fc22(h1) # 🤔 빈칸을 채워주세요
        return mean, log_var

    @staticmethod
    def reparameterize(mean, log_var):

        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)

        z = mean + std * eps
        return z

    def decode(self, z):

        h3 = F.relu(self.fc3(z))

        logits = self.fc4(h3)
        probs = torch.sigmoid(logits)

        return probs

    def forward(self, x):

        x = x.view(-1, 784)

        mu, logvar = self.encode(x)

        z = self.reparameterize(mu, logvar)

        recon = self.decode(z)

        return recon, mu, logvar

# %% [markdown]
# ### **VAE loss (ELBO)**
# * Reconsturction Loss: 복원된 이미지(`recon_x`)가 원본 이미지(`x`)와 얼마나 다른지 측정
# * KL Divergence: 잠재공간의 분포가 표준 정규븐포와 얼마나 다른지 측정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def elbo_loss(x, recon_x, mu, logvar):

    B = x.size(0)

    x = x.view(-1, 784)

    # 재구성 손실
    BCE = F.binary_cross_entropy(recon_x, x, reduction='sum') / B # 🤔 빈칸을 채워주세요

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / B # 🤔 빈칸을 채워주세요

    total_loss = BCE + KLD # 🤔 빈칸을 채워주세요

    return total_loss

# %% [markdown]
# ## **🙋 [VAE] Question 1**
# VAE의 ELBO Loss에 KL Divergence 항이 포함되는 이유를 설명해주세요.
#
#
#
# * 인코더가 만들어내는 잠재 공간의 분포 $q(z \mid x)$ 를 다루기 쉬운 표준 정규분포 $p(z)$와 비슷해지도록 유도하기 위해서이다.

# %%
vae = VAE().to(device)
optimizer = optim.Adam(vae.parameters(), lr=1e-3)

for epoch in range(epochs):


    # ========== Train ==========
    vae.train()
    train_loss = 0

    for x,_ in train_loader:

        x = x.to(device)

        recon, mu, logvar = vae(x)

        loss = elbo_loss(x,recon, mu, logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_dataset)


    # ========== Validation ==========
    vae.eval()
    val_loss = 0

    with torch.no_grad():

        for x,_ in val_loader:

            x = x.to(device)

            recon, mu, logvar = vae(x)

            loss = elbo_loss(x, recon, mu, logvar)

            val_loss += loss.item()

    val_loss /= len(val_dataset)

    print(f"[VAE] Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# [VAE] Epoch 1/30 | Train Loss: 1.3208 | Val Loss: 1.0309
# [VAE] Epoch 2/30 | Train Loss: 0.9633 | Val Loss: 0.9266
# [VAE] Epoch 3/30 | Train Loss: 0.9034 | Val Loss: 0.8933
# [VAE] Epoch 4/30 | Train Loss: 0.8788 | Val Loss: 0.8762
# [VAE] Epoch 5/30 | Train Loss: 0.8643 | Val Loss: 0.8647
# [VAE] Epoch 6/30 | Train Loss: 0.8546 | Val Loss: 0.8587
# [VAE] Epoch 7/30 | Train Loss: 0.8476 | Val Loss: 0.8530
# [VAE] Epoch 8/30 | Train Loss: 0.8419 | Val Loss: 0.8482
# [VAE] Epoch 9/30 | Train Loss: 0.8372 | Val Loss: 0.8444
# [VAE] Epoch 10/30 | Train Loss: 0.8338 | Val Loss: 0.8414
# [VAE] Epoch 11/30 | Train Loss: 0.8308 | Val Loss: 0.8386
# [VAE] Epoch 12/30 | Train Loss: 0.8281 | Val Loss: 0.8356
# [VAE] Epoch 13/30 | Train Loss: 0.8258 | Val Loss: 0.8345
# [VAE] Epoch 14/30 | Train Loss: 0.8238 | Val Loss: 0.8315
# [VAE] Epoch 15/30 | Train Loss: 0.8218 | Val Loss: 0.8289
# [VAE] Epoch 16/30 | Train Loss: 0.8204 | Val Loss: 0.8297
# [VAE] Epoch 17/30 | Train Loss: 0.8190 | Val Loss: 0.8273
# [VAE] Epoch 18/30 | Train Loss: 0.8176 | Val Loss: 0.8274
# [VAE] Epoch 19/30 | Train Loss: 0.8165 | Val Loss: 0.8249
# [VAE] Epoch 20/30 | Train Loss: 0.8149 | Val Loss: 0.8246
# [VAE] Epoch 21/30 | Train Loss: 0.8138 | Val Loss: 0.8242
# [VAE] Epoch 22/30 | Train Loss: 0.8130 | Val Loss: 0.8226
# [VAE] Epoch 23/30 | Train Loss: 0.8119 | Val Loss: 0.8226
# [VAE] Epoch 24/30 | Train Loss: 0.8108 | Val Loss: 0.8211
# [VAE] Epoch 25/30 | Train Loss: 0.8102 | Val Loss: 0.8201
# [VAE] Epoch 26/30 | Train Loss: 0.8093 | Val Loss: 0.8204
# [VAE] Epoch 27/30 | Train Loss: 0.8086 | Val Loss: 0.8195
# [VAE] Epoch 28/30 | Train Loss: 0.8077 | Val Loss: 0.8210
# [VAE] Epoch 29/30 | Train Loss: 0.8075 | Val Loss: 0.8185
# [VAE] Epoch 30/30 | Train Loss: 0.8066 | Val Loss: 0.8188

# %% [markdown]
# **VAE sampling 시각화**

# %%
with torch.no_grad():

    z = torch.randn(64,20).to(device)

    samples = vae.decode(z).view(-1,1,28,28)

    grid = make_grid(samples,8)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("VAE Samples")
plt.show()

# %% [markdown]
# ## **DCGAN(Deep Convolutional GAN) 모델 정의 및 학습**
# - Weight Initialization
#   - 모델의 가중치는 평균이 0, 표준편차가 0.02인 정규분포로 초기화
#   - 기존 GAN의 학습 불안정성을 줄이기 위해 DCGAN 논문에서 제안한 아이디어
#
# - Generator (생성자)
#   - Transposed Convolution: 저차원의 잠재 벡터를 고해상도 이미지로 확장
#   - Batch Normalization: 각 layer의 출력을 정규화하여 학습의 안정성을 높이고 gradient vanishing 문제를 해결
#   - Activation: 중간 layer에는 ReLU를 통해 빠른 학습을 진행하고, 마지막 layer에는 이미지의 픽셀 값 범위([-1, 1])를 맞추기 위해 Tanh를 사용
#
# - Discriminator (판별자)
#   - Strided Convolution: pooling 대신 stride를 사용하여 특징을 추출
#   - LeakyReLU: 음수 영역에 작은 양수 기울기를 부여하여 Gradient Vanishing 문제를 해결
#   - Activation: 마지막 layer에 sigmoid를 사용하여 real(1)/fake(0) 사이의 확률 값을 출력

# %% [markdown]
# ![The-architecture-of-vanilla-GANs.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/Natsu6767/DCGAN-PyTorch/blob/master/dcgan.py

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # [-1, 1]
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
# weight 초기화 함수

def weights_init(m):

    classname = m.__class__.__name__

    if classname.find("Conv") != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02) # 평균 0, 표준편차 0.02의 정규분포로 초기화

    elif classname.find("BatchNorm") != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
latent_size = 20

class Generator(nn.Module): # 생성자 정의

    def __init__(self):

        super().__init__()

        self.tconv1 = nn.ConvTranspose2d(latent_size,256,7,1,0,bias=False)
        self.bn1 = nn.BatchNorm2d(256)

        self.tconv2 = nn.ConvTranspose2d(256,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.tconv3 = nn.ConvTranspose2d(128,64,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(64)

        self.tconv4 = nn.ConvTranspose2d(64,1,3,1,1,bias=False)

    def forward(self,x):

        x = F.relu(self.bn1(self.tconv1(x))) # 중간층은 relu
        x = F.relu(self.bn2(self.tconv2(x)))
        x = F.relu(self.bn3(self.tconv3(x)))

        x = torch.tanh(self.tconv4(x)) # 마지막 층은 tanh 적용

        return x

# %%
class Discriminator(nn.Module): # 판별자 정의

    def __init__(self):

        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=1,out_channels=64,kernel_size=4,stride=2,padding=1,bias=False)

        self.conv2 = nn.Conv2d(64,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128,256,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(256)

        self.conv4 = nn.Conv2d(256,1,3,1,0,bias=False)

    def forward(self,x):

        x = F.leaky_relu(self.conv1(x),0.2,True) # 중간층은 leaky relu

        x = F.leaky_relu(self.bn2(self.conv2(x)),0.2,True)

        x = F.leaky_relu(self.bn3(self.conv3(x)),0.2,True)

        x = torch.sigmoid(self.conv4(x)) # 마지막 층은 sigmoid로 적용

        return x.view(-1)

# %%
G = Generator().to(device)
D = Discriminator().to(device)

G.apply(weights_init)
D.apply(weights_init)

criterion = nn.BCELoss()

optG = optim.Adam(G.parameters(),0.0002,betas=(0.5,0.999))
optD = optim.Adam(D.parameters(),0.0002,betas=(0.5,0.999))

# %%
for epoch in range(epochs):

    G.train()
    D.train()

    train_lossD = 0
    train_lossG = 0

    for x,_ in train_loader: # 루프를 통해 각 데이터 배치에 대해 학습을 진행함.

        x = x.to(device)

        real = torch.ones(x.size(0)).to(device) # 실제 이미지에 대한 레이블
        fake = torch.zeros(x.size(0)).to(device) # 생성된 이미지에 대한 레이블


        # ========== Train Discriminator ==========

        z = torch.randn(x.size(0),latent_size,1,1).to(device) # z에서 노이즈를 샘플링

        fake_img = G(z) # 생성자를 통해 fake_img 생성

        loss_real = criterion(D(x), real) # 실제 이미지에 대한 손실 계산
        loss_fake = criterion(D(fake_img.detach()), fake) # 가짜 이미지에 대한 손실 계산

        lossD = loss_real + loss_fake

        optD.zero_grad()
        lossD.backward()
        optD.step() # 가중치 업데이트


        # ========== Train Generator ==========

        lossG = criterion(D(fake_img), real) # 🤔 빈칸을 채워주세요 - 타겟 레이블로 real을 사용해야함

        optG.zero_grad()
        lossG.backward()
        optG.step()

        train_lossD += lossD.item()
        train_lossG += lossG.item()

    train_lossD /= len(train_loader)
    train_lossG /= len(train_loader)

    print(f"[DCGAN] Epoch {epoch+1}/{epochs} | Train D Loss {train_lossD:.4f} | Train G Loss {train_lossG:.4f}")
# Out:
# [DCGAN] Epoch 1/30 | Train D Loss 0.7916 | Train G Loss 1.7363
# [DCGAN] Epoch 2/30 | Train D Loss 0.9231 | Train G Loss 1.4361
# [DCGAN] Epoch 3/30 | Train D Loss 0.9869 | Train G Loss 1.3535
# [DCGAN] Epoch 4/30 | Train D Loss 1.0145 | Train G Loss 1.3046
# [DCGAN] Epoch 5/30 | Train D Loss 1.0071 | Train G Loss 1.3334
# [DCGAN] Epoch 6/30 | Train D Loss 1.0408 | Train G Loss 1.2995
# [DCGAN] Epoch 7/30 | Train D Loss 1.0049 | Train G Loss 1.3570
# [DCGAN] Epoch 8/30 | Train D Loss 0.9929 | Train G Loss 1.3884
# [DCGAN] Epoch 9/30 | Train D Loss 0.9997 | Train G Loss 1.3921
# [DCGAN] Epoch 10/30 | Train D Loss 0.9955 | Train G Loss 1.4087
# [DCGAN] Epoch 11/30 | Train D Loss 0.9620 | Train G Loss 1.4550
# [DCGAN] Epoch 12/30 | Train D Loss 0.9669 | Train G Loss 1.4563
# [DCGAN] Epoch 13/30 | Train D Loss 0.9354 | Train G Loss 1.5168
# [DCGAN] Epoch 14/30 | Train D Loss 0.9266 | Train G Loss 1.5358
# [DCGAN] Epoch 15/30 | Train D Loss 0.9224 | Train G Loss 1.5338
# [DCGAN] Epoch 16/30 | Train D Loss 0.9026 | Train G Loss 1.5897
# [DCGAN] Epoch 17/30 | Train D Loss 0.8728 | Train G Loss 1.6293
# [DCGAN] Epoch 18/30 | Train D Loss 0.8786 | Train G Loss 1.6456
# [DCGAN] Epoch 19/30 | Train D Loss 0.8513 | Train G Loss 1.6828
# [DCGAN] Epoch 20/30 | Train D Loss 0.8522 | Train G Loss 1.6999
# [DCGAN] Epoch 21/30 | Train D Loss 0.8508 | Train G Loss 1.7244
# [DCGAN] Epoch 22/30 | Train D Loss 0.8334 | Train G Loss 1.7259
# [DCGAN] Epoch 23/30 | Train D Loss 0.8053 | Train G Loss 1.7822
# [DCGAN] Epoch 24/30 | Train D Loss 0.7986 | Train G Loss 1.8318
# [DCGAN] Epoch 25/30 | Train D Loss 0.8011 | Train G Loss 1.8323
# [DCGAN] Epoch 26/30 | Train D Loss 0.7826 | Train G Loss 1.8551
# [DCGAN] Epoch 27/30 | Train D Loss 0.7794 | Train G Loss 1.8810
# [DCGAN] Epoch 28/30 | Train D Loss 0.7957 | Train G Loss 1.8605
# [DCGAN] Epoch 29/30 | Train D Loss 0.7700 | Train G Loss 1.9023
# [DCGAN] Epoch 30/30 | Train D Loss 0.7508 | Train G Loss 1.9443

# %% [markdown]
# **DCGAN Sampling 시각화**

# %%
G.eval()

with torch.no_grad():

    z = torch.randn(64,latent_size,1,1).to(device)

    samples = G(z)

grid = make_grid(samples,8,normalize=True)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("DCGAN Samples")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **🙋 [GAN] Question 2-1**
# VAE와 DCGAN으로 MNIST 이미지를 생성한 결과 VAE는 흐릿한 이미지, DCGAN은 선명한 이미지가 생성된 것을 알 수 있습니다. 그 이유를 VAE와 GAN의 특징과 학습 방식을 포함하여 설명해주세요.
#
# * VAE는 손실 함수로 재구성 손실과 정규화 손실을 합쳐서 사용한다. 여기서 재구성 손실은 원본 데이터와 디코더가 복원한 데이터의 픽셀 값 차이가 최소화되도록 유도한다. 이로 인해 평균적인 결과를 출력하게 되고, 이미지가 흐릿해지는 문제가 발생한다. 하지만 GAN기반의 모델은 재구성 손실을 사용하지 않고 MinMax Game을 기반으로 학습한다. 이 과정에서 생성자는 판별자를 속여야하기 때문에 더 선명한 이미지를 생성하게 된다. 따라서 VAE보다 더 선명한 이미지를 생성하게된다.

# %% [markdown]
# ## **🙋 [GAN] Question 2-2**
# GAN 학습 과정에서 Generator의 Loss가 증가하는 것이 반드시 모델 성능 악화를 의미하지 않는 이유는 무엇인지 설명해주세요.
#
# * Generator의 Loss가 올랐다는 것은 생성된 데이터의 품질이 악화되었다고도 해석이 가능하지만, 현재 Discriminator의 성능이 향상했다는 것으로도 해석이 가능하기 때문이다.

# %% [markdown]
# 수고하셨습니다 ☺️
